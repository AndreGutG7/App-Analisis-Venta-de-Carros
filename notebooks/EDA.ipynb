# %%
# Se instalan las librerías directamente en el cuaderno
# %pip install pandas plotly-express nbformat

import pandas as pd
import plotly.express as px

# Cargar los datos 
try:
    df = pd.read_csv('../vehicles_us.csv')
    print("¡Datos cargados correctamente!")
    
    # Crear el histograma
    fig = px.histogram(df, x="odometer")
    fig.show(renderer="iframe")
except Exception as e:
    print(f"Hubo un error al cargar los datos: {e}")
# Out:
# Requirement already satisfied: pandas in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (3.0.1)
# Requirement already satisfied: plotly-express in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: nbformat in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (5.10.4)
# Requirement already satisfied: numpy>=2.3.3 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: plotly>=4.1.0 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from plotly-express) (6.6.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from plotly-express) (0.14.6)
# Requirement already satisfied: scipy>=0.18 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from plotly-express) (1.17.1)
# Requirement already satisfied: patsy>=0.5 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from plotly-express) (1.0.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.4)
# Requirement already satisfied: narwhals>=1.15.1 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from plotly>=4.1.0->plotly-express) (2.18.0)
# Requirement already satisfied: packaging in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from plotly>=4.1.0->plotly-express) (26.0)
# Requirement already satisfied: six>=1.5 in c:\analisis de datos tripleten\git proyecto\app-analisis-venta-de-carros\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ¡Datos cargados correctamente!
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_6.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
